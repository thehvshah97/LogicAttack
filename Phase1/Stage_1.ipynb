# %%
import pandas as pd

# %%
#Reading csv file
df_test = pd.read_csv('Flan_Dataset_Only_True.csv')
df_test
# Out:
#      Unnamed: 0                                            premise  \
# 0             0  Climate is generally described in terms of loc...
# 1             1       temperature and moisture varies by alltitude
# 2             2      temperature and moisture is changing globally
# 3             3  average weather conditions are generally descr...
# 4             4  Climate is usually described in terms of tempe...
# ..          ...                                                ...
# 919         919  Kidney failure may be treated by the mechanica...
# 920         920  One effect of diabetes can be treated with dia...
# 921         921              A lack of dialysis may lead to death.
# 922         922  Kidney failure may be treated by cleaning the ...
# 923         923         Renal failure may be treated with dialysis
#
#                                             hypothesis  \
# 0    Climate is generally described in terms of loc...
# 1            Temperature and moisture vary by altitude
# 2       Temperature and moisture are changing globally
# 3    Average weather conditions are generally descr...
# 4    Climate is described in terms of temperature a...
# ..                                                 ...
# 919  Kidney failure may be treated by the mechanica...
# 920  Dialysis can be used to treat one effect of di...
# 921  The consequences of not getting dialysis when ...
# 922  Kidney failure may be treated by cleaning the ...
# 923        Renal failure may be treated with dialysis.
#
#                                              premise_n  \
# 0    Climate is not specifically described in terms...
# 1    Temperature and moisture do not vary by altitude.
# 2    Temperature and moisture are not changing glob...
# 3    Average weather conditions are not generally d...
# 4    Climate is not usually described in terms of t...
# ..                                                 ...
# 919  Kidney failure may not always be treated by th...
# 920  One effect of diabetes may not always be treat...
# 921   A lack of dialysis may not always lead to death.
# 922  Kidney failure may not always be treated by cl...
# 923  Renal failure may not always be treated with d...
#
#                                           hypothesis_n  \
# 0    Climate is not specifically described in terms...
# 1    Temperature and moisture do not vary by altitude.
# 2    Temperature and moisture are not changing glob...
# 3    Average weather conditions are not generally d...
# 4    Climate is not described in terms of temperatu...
# ..                                                 ...
# 919  Kidney failure may not be treated by the mecha...
# 920  Dialysis cannot be used to treat one effect of...
# 921  The consequences of not getting dialysis when ...
# 922  Kidney failure may not be treated by cleaning ...
# 923    Renal failure may not be treated with dialysis.
#
#                                                context  \
# 0    Climate is generally described in terms of loc...
# 1         temperature and moisture varies by alltitude
# 2        temperature and moisture is changing globally
# 3    average weather conditions are generally descr...
# 4    Climate is usually described in terms of tempe...
# ..                                                 ...
# 919  Kidney failure may be treated by the mechanica...
# 920  One effect of diabetes can be treated with dia...
# 921              A lack of dialysis may lead to death.
# 922  Kidney failure may be treated by cleaning the ...
# 923         Renal failure may be treated with dialysis
#
#                                     formatted_question answerKey
# 0    Climate is generally described in terms of wha...         F
# 1    what varies by altitude? (A) h2o composition (...         G
# 2    What is changing globally? (A) the number of c...         D
# 3    what are generally described in terms of tempe...         F
# 4    What is described in terms of temperature and ...         B
# ..                                                 ...       ...
# 919  Kidney failure may be treated by the mechanica...         B
# 920  What can dialysis be used to treat? (A) the pa...         G
# 921  What are the consequences of not getting dialy...         C
# 922  Kidney failure may be treated by cleaning the ...         E
# 923  What may renal failure be treated with? (A) La...         D
#
# [924 rows x 8 columns]

# %%
#Considering only those records marked as entailment
df_test_entailments = df_test[df_test["gold_label"] == "entailment"]
df_test_entailments
# Out:
#                                                premise  \
# 0    Climate is generally described in terms of loc...
# 1         temperature and moisture varies by alltitude
# 2        temperature and moisture is changing globally
# 3    average weather conditions are generally descr...
# 4    Climate is usually described in terms of tempe...
# ..                                                 ...
# 887  Kidney failure may be treated by the mechanica...
# 888  One effect of diabetes can be treated with dia...
# 889              A lack of dialysis may lead to death.
# 890  Kidney failure may be treated by cleaning the ...
# 891         Renal failure may be treated with dialysis
#
#                                             hypothesis  \
# 0    Climate is generally described in terms of loc...
# 1            Temperature and moisture vary by altitude
# 2       Temperature and moisture are changing globally
# 3    Average weather conditions are generally descr...
# 4    Climate is described in terms of temperature a...
# ..                                                 ...
# 887  Kidney failure may be treated by the mechanica...
# 888  Dialysis can be used to treat one effect of di...
# 889  The consequences of not getting dialysis when ...
# 890  Kidney failure may be treated by cleaning the ...
# 891        Renal failure may be treated with dialysis.
#
#                                              premise_n  \
# 0    Climate is not specifically described in terms...
# 1    Temperature and moisture do not vary by altitude.
# 2    Temperature and moisture are not changing glob...
# 3    Average weather conditions are not generally d...
# 4    Climate is not usually described in terms of t...
# ..                                                 ...
# 887  Kidney failure may not always be treated by th...
# 888  One effect of diabetes may not always be treat...
# 889   A lack of dialysis may not always lead to death.
# 890  Kidney failure may not always be treated by cl...
# 891  Renal failure may not always be treated with d...
#
#                                           hypothesis_n  \
# 0    Climate is not specifically described in terms...
# 1    Temperature and moisture do not vary by altitude.
# 2    Temperature and moisture are not changing glob...
# 3    Average weather conditions are not generally d...
# 4    Climate is not described in terms of temperatu...
# ..                                                 ...
# 887  Kidney failure may not be treated by the mecha...
# 888  Dialysis cannot be used to treat one effect of...
# 889  The consequences of not getting dialysis when ...
# 890  Kidney failure may not be treated by cleaning ...
# 891    Renal failure may not be treated with dialysis.
#
#                                          prompt_output  gold_label  \
# 0    In this task, you are given two sentences (Pre...  entailment
# 1    In this task, you are given two sentences (Pre...  entailment
# 2    In this task, you are given two sentences (Pre...  entailment
# 3    In this task, you are given two sentences (Pre...  entailment
# 4    In this task, you are given two sentences (Pre...  entailment
# ..                                                 ...         ...
# 887  In this task, you are given two sentences (Pre...  entailment
# 888  In this task, you are given two sentences (Pre...  entailment
# 889  In this task, you are given two sentences (Pre...  entailment
# 890  In this task, you are given two sentences (Pre...  entailment
# 891  In this task, you are given two sentences (Pre...  entailment
#
#     predicted_label
# 0        entailment
# 1        entailment
# 2        entailment
# 3        entailment
# 4        entailment
# ..              ...
# 887      entailment
# 888      entailment
# 889      entailment
# 890      entailment
# 891      entailment
#
# [892 rows x 7 columns]

# %%
def modus_tollens(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2):
    while positive_sentence1[-1]=='.':
        positive_sentence1 = positive_sentence1[:-1]
    while negative_sentence1[-1]=='.':
        negative_sentence1 = negative_sentence1[:-1]
    while positive_sentence2[-1]=='.':
        positive_sentence2 = positive_sentence2[:-1]
    while negative_sentence2[-1]=='.':
        negative_sentence2 = negative_sentence2[:-1]
    sentence1 = positive_sentence1[0].lower() + positive_sentence1[1:]
    sentence2 = positive_sentence2[0].lower() + positive_sentence2[1:]
    premise =  "If " + sentence1 + ", then " + sentence2 + ". " + negative_sentence2+"."
    hypothesis = negative_sentence1+"."
    return premise,hypothesis

# %%
def constructive_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4):
    while positive_sentence1[-1]=='.':
        positive_sentence1 = positive_sentence1[:-1]
    while negative_sentence1[-1]=='.':
        negative_sentence1 = negative_sentence1[:-1]
    while positive_sentence2[-1]=='.':
        positive_sentence2 = positive_sentence2[:-1]
    while negative_sentence2[-1]=='.':
        negative_sentence2 = negative_sentence2[:-1]
    while positive_sentence3[-1]=='.':
        positive_sentence3 = positive_sentence3[:-1]
    while negative_sentence3[-1]=='.':
        negative_sentence3 = negative_sentence3[:-1]
    while positive_sentence4[-1]=='.':
        positive_sentence4 = positive_sentence4[:-1]
    while negative_sentence4[-1]=='.':
        negative_sentence4 = negative_sentence4[:-1]
    sentence1 = positive_sentence1[0].lower() + positive_sentence1[1:]
    sentence2 = positive_sentence2[0].lower() + positive_sentence2[1:]
    sentence3 = positive_sentence3[0].lower() + positive_sentence3[1:]
    sentence4 = positive_sentence4[0].lower() + positive_sentence4[1:]
    premise = "If " + sentence1 +", then " + sentence2+". And if "+ sentence3 +", then " + sentence4+". But either "+ sentence1 + " or " + sentence3+"."
    hypothesis = "Either "+sentence2 +" or " + sentence4+"."
    return premise,hypothesis

# %%
def destructive_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4):
    while positive_sentence1[-1]=='.':
        positive_sentence1 = positive_sentence1[:-1]
    while negative_sentence1[-1]=='.':
        negative_sentence1 = negative_sentence1[:-1]
    while positive_sentence2[-1]=='.':
        positive_sentence2 = positive_sentence2[:-1]
    while negative_sentence2[-1]=='.':
        negative_sentence2 = negative_sentence2[:-1]
    while positive_sentence3[-1]=='.':
        positive_sentence3 = positive_sentence3[:-1]
    while negative_sentence3[-1]=='.':
        negative_sentence3 = negative_sentence3[:-1]
    while positive_sentence4[-1]=='.':
        positive_sentence4 = positive_sentence4[:-1]
    while negative_sentence4[-1]=='.':
        negative_sentence4 = negative_sentence4[:-1]
    sentence1 = positive_sentence1[0].lower() + positive_sentence1[1:]
    sentence2 = positive_sentence2[0].lower() + positive_sentence2[1:]
    sentence3 = positive_sentence3[0].lower() + positive_sentence3[1:]
    sentence4 = positive_sentence4[0].lower() + positive_sentence4[1:]
    sentence1_n = negative_sentence1[0].lower() + negative_sentence1[1:]
    sentence2_n = negative_sentence2[0].lower() + negative_sentence2[1:]
    sentence3_n = negative_sentence3[0].lower() + negative_sentence3[1:]
    sentence4_n = negative_sentence4[0].lower() + negative_sentence4[1:]
    premise = "If " + sentence1 +", then " + sentence2+". And if "+ sentence3 +", then " + sentence4+". But either "+ sentence2_n + " or " + sentence4_n+"."
    hypothesis = "Either "+ sentence1_n  +" or " + sentence3_n +"."
    return premise,hypothesis

# %%
def bidirectional_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4):
    while positive_sentence1[-1]=='.':
        positive_sentence1 = positive_sentence1[:-1]
    while negative_sentence1[-1]=='.':
        negative_sentence1 = negative_sentence1[:-1]
    while positive_sentence2[-1]=='.':
        positive_sentence2 = positive_sentence2[:-1]
    while negative_sentence2[-1]=='.':
        negative_sentence2 = negative_sentence2[:-1]
    while positive_sentence3[-1]=='.':
        positive_sentence3 = positive_sentence3[:-1]
    while negative_sentence3[-1]=='.':
        negative_sentence3 = negative_sentence3[:-1]
    while positive_sentence4[-1]=='.':
        positive_sentence4 = positive_sentence4[:-1]
    while negative_sentence4[-1]=='.':
        negative_sentence4 = negative_sentence4[:-1]

    sentence1 = positive_sentence1[0].lower() + positive_sentence1[1:]
    sentence2 = positive_sentence2[0].lower() + positive_sentence2[1:]
    sentence3 = positive_sentence3[0].lower() + positive_sentence3[1:]
    sentence4 = positive_sentence4[0].lower() + positive_sentence4[1:]
    sentence1_n = negative_sentence1[0].lower() + negative_sentence1[1:]
    sentence2_n = negative_sentence2[0].lower() + negative_sentence2[1:]
    sentence3_n = negative_sentence3[0].lower() + negative_sentence3[1:]
    sentence4_n = negative_sentence4[0].lower() + negative_sentence4[1:]
    premise = "If " + sentence1 +", then " + sentence2+". And if "+ sentence3 +", then " + sentence4+". But either "+ sentence1 + " or " + sentence4_n+"."
    hypothesis = "Either "+sentence2 +" or " + sentence3_n+"."
    return premise,hypothesis

# %%
def transportation_1(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2):
    while positive_sentence1[-1]=='.':
        positive_sentence1 = positive_sentence1[:-1]
    while negative_sentence1[-1]=='.':
        negative_sentence1 = negative_sentence1[:-1]
    while positive_sentence2[-1]=='.':
        positive_sentence2 = positive_sentence2[:-1]
    while negative_sentence2[-1]=='.':
        negative_sentence2 = negative_sentence2[:-1]

    sentence1 = positive_sentence1[0].lower() + positive_sentence1[1:]
    sentence2 = positive_sentence2[0].lower() + positive_sentence2[1:]
    sentence1_n = negative_sentence1[0].lower() + negative_sentence1[1:]
    sentence2_n = negative_sentence2[0].lower() + negative_sentence2[1:]
    premise =  "If " + sentence1 + ", then " + sentence2 + "."
    hypothesis = "If " + sentence2_n + ", then " + sentence1_n + "."
    return premise,hypothesis

# %%
def transportation_2(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2):
    premise,hypothesis = transportation_1(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2)
    return hypothesis,premise

# %%
def material_implication_1(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2):
    while positive_sentence1[-1]=='.':
        positive_sentence1 = positive_sentence1[:-1]
    while negative_sentence1[-1]=='.':
        negative_sentence1 = negative_sentence1[:-1]
    while positive_sentence2[-1]=='.':
        positive_sentence2 = positive_sentence2[:-1]
    while negative_sentence2[-1]=='.':
        negative_sentence2 = negative_sentence2[:-1]

    sentence1 = positive_sentence1[0].lower() + positive_sentence1[1:]
    sentence2 = positive_sentence2[0].lower() + positive_sentence2[1:]
    sentence1_n = negative_sentence1[0].lower() + negative_sentence1[1:]
    sentence2_n = negative_sentence2[0].lower() + negative_sentence2[1:]
    premise =  "If " + sentence1 + ", then " + sentence2 + "."
    hypothesis = "Either " + sentence1_n + " or " + sentence2 + "."
    return premise,hypothesis

# %%
def material_implication_2(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2):
    premise,hypothesis = material_implication_1(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2)
    return hypothesis,premise

# %%
def negate_hypthesis(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2):
    while positive_sentence1[-1]=='.':
        positive_sentence1 = positive_sentence1[:-1]
    while negative_sentence1[-1]=='.':
        negative_sentence1 = negative_sentence1[:-1]
    while positive_sentence2[-1]=='.':
        positive_sentence2 = positive_sentence2[:-1]
    while negative_sentence2[-1]=='.':
        negative_sentence2 = negative_sentence2[:-1]
    premise = positive_sentence1 +"."
    hypothesis = negative_sentence2 + "."
    return premise,hypothesis

# %%
df_result = pd.DataFrame(columns=['premise', 'hypothesis','propositional_logic_rule','context','question','answer'])
df_result
# Out:
# Empty DataFrame
# Columns: [premise, hypothesis, propositional_logic_rule, context, question, answer]
# Index: []

# %%
#Expressions involving 1 row
df_test_entailments = df_test
for i,row in df_test_entailments.iterrows():
    positive_sentence1 = row["premise"]
    negative_sentence1 = row["premise_n"]
    positive_sentence2 = row["hypothesis"]
    negative_sentence2 = row["hypothesis_n"]
    context = row["context"]
    question = row["formatted_question"]
    answer = row["answerKey"]
    modus_tollens_premise, modus_tollens_hypothesis = modus_tollens(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2)
    row = [modus_tollens_premise, modus_tollens_hypothesis,'Modus Tollens',context,question,answer]
    df_result.loc[len(df_result)] = row

    transportation_1_premise, transportation_1_hypothesis = transportation_1(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2)
    row = [transportation_1_premise, transportation_1_hypothesis,'Transportation 1',context,question,answer]
    df_result.loc[len(df_result)] = row

    transportation_2_premise, transportation_2_hypothesis = transportation_2(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2)
    row = [transportation_2_premise, transportation_2_hypothesis,'Transportation 2',context,question,answer]
    df_result.loc[len(df_result)] = row

    material_implication_1_premise, material_implication_1_hypothesis = material_implication_1(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2)
    row = [material_implication_1_premise, material_implication_1_hypothesis,'Material Implication 1',context,question,answer]
    df_result.loc[len(df_result)] = row

    material_implication_2_premise, material_implication_2_hypothesis = material_implication_2(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2)
    row = [material_implication_2_premise, material_implication_2_hypothesis,'Material Implication 2',context,question,answer]
    df_result.loc[len(df_result)] = row

    negate_hypthesis_premise, negate_hypthesis_hypothesis = negate_hypthesis(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2)
    row = [negate_hypthesis_premise, negate_hypthesis_hypothesis,'Negate Hypothesis',context,question,answer]
    df_result.loc[len(df_result)] = row

# %%
df_result
# Out:
#                                                 premise  \
# 0     If climate is generally described in terms of ...
# 1     If climate is generally described in terms of ...
# 2     If climate is not specifically described in te...
# 3     If climate is generally described in terms of ...
# 4     Either climate is not specifically described i...
# ...                                                 ...
# 5539  If renal failure may be treated with dialysis,...
# 5540  If renal failure may not be treated with dialy...
# 5541  If renal failure may be treated with dialysis,...
# 5542  Either renal failure may not always be treated...
# 5543        Renal failure may be treated with dialysis.
#
#                                              hypothesis  \
# 0     Climate is not specifically described in terms...
# 1     If climate is not specifically described in te...
# 2     If climate is generally described in terms of ...
# 3     Either climate is not specifically described i...
# 4     If climate is generally described in terms of ...
# ...                                                 ...
# 5539  If renal failure may not be treated with dialy...
# 5540  If renal failure may be treated with dialysis,...
# 5541  Either renal failure may not always be treated...
# 5542  If renal failure may be treated with dialysis,...
# 5543    Renal failure may not be treated with dialysis.
#
#      propositional_logic_rule  \
# 0               Modus Tollens
# 1            Transportation 1
# 2            Transportation 2
# 3      Material Implication 1
# 4      Material Implication 2
# ...                       ...
# 5539         Transportation 1
# 5540         Transportation 2
# 5541   Material Implication 1
# 5542   Material Implication 2
# 5543        Negate Hypothesis
#
#                                                 context  \
# 0     Climate is generally described in terms of loc...
# 1     Climate is generally described in terms of loc...
# 2     Climate is generally described in terms of loc...
# 3     Climate is generally described in terms of loc...
# 4     Climate is generally described in terms of loc...
# ...                                                 ...
# 5539         Renal failure may be treated with dialysis
# 5540         Renal failure may be treated with dialysis
# 5541         Renal failure may be treated with dialysis
# 5542         Renal failure may be treated with dialysis
# 5543         Renal failure may be treated with dialysis
#
#                                                question answer
# 0     Climate is generally described in terms of wha...      F
# 1     Climate is generally described in terms of wha...      F
# 2     Climate is generally described in terms of wha...      F
# 3     Climate is generally described in terms of wha...      F
# 4     Climate is generally described in terms of wha...      F
# ...                                                 ...    ...
# 5539  What may renal failure be treated with? (A) La...      D
# 5540  What may renal failure be treated with? (A) La...      D
# 5541  What may renal failure be treated with? (A) La...      D
# 5542  What may renal failure be treated with? (A) La...      D
# 5543  What may renal failure be treated with? (A) La...      D
#
# [5544 rows x 6 columns]

# %%
df_test_entailments.shape
# Out:
# (924, 8)

# %%
#Expressions involving 2 rows
positive_sentence1 = df_test_entailments.iloc[0]["premise"]
negative_sentence1 = df_test_entailments.iloc[0]["premise_n"]
positive_sentence2 = df_test_entailments.iloc[0]["hypothesis"]
negative_sentence2 = df_test_entailments.iloc[0]["hypothesis_n"]
context1 = df_test_entailments.iloc[0]["context"]
question1 = df_test_entailments.iloc[0]["formatted_question"]
answer1 = df_test_entailments.iloc[0]["answerKey"]
context2=""
question2=""
answer2=""
positive_sentence3 = ""
negative_sentence3 = ""
positive_sentence4 = ""
negative_sentence4 = ""
for i,row in df_test_entailments.iterrows():
    #Set first 2 sentences
    if i==0:
        continue
    positive_sentence3 = row["premise"]
    negative_sentence3 = row["premise_n"]
    positive_sentence4 = row["hypothesis"]
    negative_sentence4 = row["hypothesis_n"]
    context2 = row["context"]
    question2 = row["formatted_question"]
    answer2 = row["answerKey"]
    context = context1+". "+context2
    question = question1 + ". "+question2
    answer = answer1 + ". " + answer2
    constructive_dilemma_premise, constructive_dilemma_hypothesis = constructive_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4)
    row = [constructive_dilemma_premise, constructive_dilemma_hypothesis,'Constructive Dilemma',context,question,answer]
    df_result.loc[len(df_result)] = row

    destructive_dilemma_premise, destructive_dilemma_hypothesis = destructive_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4)
    row = [destructive_dilemma_premise, destructive_dilemma_hypothesis,'Destructive Dilemma',context,question,answer]
    df_result.loc[len(df_result)] = row

    bidirectional_dilemma_premise, bidirectional_dilemma_hypothesis = bidirectional_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4)
    row = [bidirectional_dilemma_premise, bidirectional_dilemma_hypothesis,'Bidirectional Dilemma',context,question,answer]
    df_result.loc[len(df_result)] = row

    positive_sentence1 = positive_sentence3
    negative_sentence1 = negative_sentence3
    positive_sentence2 = positive_sentence4
    negative_sentence2 = negative_sentence4
    context1 = context2
    question1 = question2
    answer1 = answer2

# %%
df_result[-2:-1]
# Out:
#                                                 premise  \
# 8311  If kidney failure may be treated by cleaning t...
#
#                                              hypothesis  \
# 8311  Either kidney failure may not always be treate...
#
#      propositional_logic_rule  \
# 8311      Destructive Dilemma
#
#                                                 context  \
# 8311  Kidney failure may be treated by cleaning the ...
#
#                                                question answer
# 8311  Kidney failure may be treated by cleaning the ...   E. D

# %%
positive_sentence3 = df_test_entailments.iloc[0]["premise"]
negative_sentence3 = df_test_entailments.iloc[0]["premise_n"]
positive_sentence4 = df_test_entailments.iloc[0]["hypothesis"]
negative_sentence4 = df_test_entailments.iloc[0]["hypothesis_n"]
context1 = df_test_entailments.iloc[0]["context"]
question1 = df_test_entailments.iloc[0]["formatted_question"]
answer1 = df_test_entailments.iloc[0]["answerKey"]
context = context1 + ". "+context2
question = question1 +". "+ question2
answer = answer1 + ". "+answer2
constructive_dilemma_premise, constructive_dilemma_hypothesis = constructive_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4)
row = [constructive_dilemma_premise, constructive_dilemma_hypothesis,'Constructive Dilemma',context, question, answer]
df_result.loc[len(df_result)] = row

destructive_dilemma_premise, destructive_dilemma_hypothesis = destructive_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4)
row = [destructive_dilemma_premise, destructive_dilemma_hypothesis,'Destructive Dilemma',context, question, answer]
df_result.loc[len(df_result)] = row

bidirectional_dilemma_premise, bidirectional_dilemma_hypothesis = bidirectional_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4)
row = [bidirectional_dilemma_premise, bidirectional_dilemma_hypothesis,'Bidirectional Dilemma',context, question, answer]
df_result.loc[len(df_result)] = row

# %%
df_result
# Out:
#                                                 premise  \
# 0     If climate is generally described in terms of ...
# 1     If climate is generally described in terms of ...
# 2     If climate is not specifically described in te...
# 3     If climate is generally described in terms of ...
# 4     Either climate is not specifically described i...
# ...                                                 ...
# 8311  If kidney failure may be treated by cleaning t...
# 8312  If kidney failure may be treated by cleaning t...
# 8313  If renal failure may be treated with dialysis,...
# 8314  If renal failure may be treated with dialysis,...
# 8315  If renal failure may be treated with dialysis,...
#
#                                              hypothesis  \
# 0     Climate is not specifically described in terms...
# 1     If climate is not specifically described in te...
# 2     If climate is generally described in terms of ...
# 3     Either climate is not specifically described i...
# 4     If climate is generally described in terms of ...
# ...                                                 ...
# 8311  Either kidney failure may not always be treate...
# 8312  Either kidney failure may be treated by cleani...
# 8313  Either renal failure may be treated with dialy...
# 8314  Either renal failure may not always be treated...
# 8315  Either renal failure may be treated with dialy...
#
#      propositional_logic_rule  \
# 0               Modus Tollens
# 1            Transportation 1
# 2            Transportation 2
# 3      Material Implication 1
# 4      Material Implication 2
# ...                       ...
# 8311      Destructive Dilemma
# 8312    Bidirectional Dilemma
# 8313     Constructive Dilemma
# 8314      Destructive Dilemma
# 8315    Bidirectional Dilemma
#
#                                                 context  \
# 0     Climate is generally described in terms of loc...
# 1     Climate is generally described in terms of loc...
# 2     Climate is generally described in terms of loc...
# 3     Climate is generally described in terms of loc...
# 4     Climate is generally described in terms of loc...
# ...                                                 ...
# 8311  Kidney failure may be treated by cleaning the ...
# 8312  Kidney failure may be treated by cleaning the ...
# 8313  Climate is generally described in terms of loc...
# 8314  Climate is generally described in terms of loc...
# 8315  Climate is generally described in terms of loc...
#
#                                                question answer
# 0     Climate is generally described in terms of wha...      F
# 1     Climate is generally described in terms of wha...      F
# 2     Climate is generally described in terms of wha...      F
# 3     Climate is generally described in terms of wha...      F
# 4     Climate is generally described in terms of wha...      F
# ...                                                 ...    ...
# 8311  Kidney failure may be treated by cleaning the ...   E. D
# 8312  Kidney failure may be treated by cleaning the ...   E. D
# 8313  Climate is generally described in terms of wha...   F. D
# 8314  Climate is generally described in terms of wha...   F. D
# 8315  Climate is generally described in terms of wha...   F. D
#
# [8316 rows x 6 columns]

# %%
df_result.to_csv('Final_FLAN_Attacks_Dataset.csv',encoding="utf-8", index=False)
