# %%
import pandas as pd

# %%
#Reading csv file
df_test = pd.read_csv('set-5-sanketDuhoon.csv', usecols = ['Hypothesis','Premises','Negate Hypothesis','Negate Premise'])
df_test
# Out:
#                                             Hypothesis  \
# 0                           Moistened Food is a bolus.
# 1                    Liquids make food easier to chew.
# 2                          Cows make nutritious fluid.
# 3         Milk is nutritious and prevents dehydration.
# 4        Cow milk has Vitamin D, making it nutritious.
# ..                                                 ...
# 181  Kidney failure may be treated by the mechanica...
# 182  Dialysis can be used to treat one effect of di...
# 183  The consequences of not getting dialysis when ...
# 184  Kidney failure may be treated by cleaning the ...
# 185        Renal failure may be treated with dialysis.
#
#                                               Premises  \
# 0                            a bolus is moistened food
# 1    Food is easier to chew because it is moistened...
# 2                           cows make nutritious fluid
# 3         Milk is nutritious and prevents dehydration.
# 4    Milk is nutritious because it has vitamin D an...
# ..                                                 ...
# 181  Kidney failure may be treated by the mechanica...
# 182  One effect of diabetes can be treated with dia...
# 183              A lack of dialysis may lead to death.
# 184  Kidney failure may be treated by cleaning the ...
# 185         Renal failure may be treated with dialysis
#
#                                      Negate Hypothesis  \
# 0                       Moistened food is not a bolus.
# 1             Liquids do not make food easier to chew.
# 2                   Cows do not make nutritious fluid.
# 3    Milk is not nutritious and does not prevent de...
# 4    Cow milk lacks Vitamin D, making it not nutrit...
# ..                                                 ...
# 181  Kidney failure may not be treated by the mecha...
# 182  Dialysis cannot be used to treat one effect of...
# 183  The consequences of not getting dialysis when ...
# 184  Kidney failure may not be treated by cleaning ...
# 185    Renal failure may not be treated with dialysis.
#
#                                         Negate Premise
# 0                        a bolus is not moistened food
# 1    Food is not easier to chew because it is moist...
# 2                    cows do not make nutritious fluid
# 3    Milk is not nutritious and does not prevent de...
# 4    Milk is not nutritious because it has vitamin ...
# ..                                                 ...
# 181  Kidney failure may not always be treated by th...
# 182  One effect of diabetes may not always be treat...
# 183   A lack of dialysis may not always lead to death.
# 184  Kidney failure may not always be treated by cl...
# 185  Renal failure may not always be treated with d...
#
# [186 rows x 4 columns]

# %%
hypothesis = df_test['Hypothesis'].values.tolist()
premise = df_test['Premises'].values.tolist()
premise_n = df_test['Negate Premise'].values.tolist()
hypothesis_n = df_test['Negate Hypothesis'].values.tolist()

# %%
def modus_tollens(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2):
    while positive_sentence1[-1]=='.':
        positive_sentence1 = positive_sentence1[:-1]
    while negative_sentence1[-1]=='.':
        negative_sentence1 = negative_sentence1[:-1]
    while positive_sentence2[-1]=='.':
        positive_sentence2 = positive_sentence2[:-1]
    while negative_sentence2[-1]=='.':
        negative_sentence2 = negative_sentence2[:-1]
    sentence1 = positive_sentence1[0].lower() + positive_sentence1[1:]
    sentence2 = positive_sentence2[0].lower() + positive_sentence2[1:]
    premise =  "If " + sentence1 + ", then " + sentence2 + ". " + negative_sentence2+"."
    hypothesis = negative_sentence1+"."
    return premise,hypothesis

# %%
def constructive_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4):
    while positive_sentence1[-1]=='.':
        positive_sentence1 = positive_sentence1[:-1]
    while negative_sentence1[-1]=='.':
        negative_sentence1 = negative_sentence1[:-1]
    while positive_sentence2[-1]=='.':
        positive_sentence2 = positive_sentence2[:-1]
    while negative_sentence2[-1]=='.':
        negative_sentence2 = negative_sentence2[:-1]
    while positive_sentence3[-1]=='.':
        positive_sentence3 = positive_sentence3[:-1]
    while negative_sentence3[-1]=='.':
        negative_sentence3 = negative_sentence3[:-1]
    while positive_sentence4[-1]=='.':
        positive_sentence4 = positive_sentence4[:-1]
    while negative_sentence4[-1]=='.':
        negative_sentence4 = negative_sentence4[:-1]
    sentence1 = positive_sentence1[0].lower() + positive_sentence1[1:]
    sentence2 = positive_sentence2[0].lower() + positive_sentence2[1:]
    sentence3 = positive_sentence3[0].lower() + positive_sentence3[1:]
    sentence4 = positive_sentence4[0].lower() + positive_sentence4[1:]
    premise = "If " + sentence1 +", then " + sentence2+". And if "+ sentence3 +", then " + sentence4+". But either "+ sentence1 + " or " + sentence3+"."
    hypothesis = "Either "+sentence2 +" or " + sentence4+"."
    return premise,hypothesis

# %%
def destructive_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4):
    while positive_sentence1[-1]=='.':
        positive_sentence1 = positive_sentence1[:-1]
    while negative_sentence1[-1]=='.':
        negative_sentence1 = negative_sentence1[:-1]
    while positive_sentence2[-1]=='.':
        positive_sentence2 = positive_sentence2[:-1]
    while negative_sentence2[-1]=='.':
        negative_sentence2 = negative_sentence2[:-1]
    while positive_sentence3[-1]=='.':
        positive_sentence3 = positive_sentence3[:-1]
    while negative_sentence3[-1]=='.':
        negative_sentence3 = negative_sentence3[:-1]
    while positive_sentence4[-1]=='.':
        positive_sentence4 = positive_sentence4[:-1]
    while negative_sentence4[-1]=='.':
        negative_sentence4 = negative_sentence4[:-1]
    sentence1 = positive_sentence1[0].lower() + positive_sentence1[1:]
    sentence2 = positive_sentence2[0].lower() + positive_sentence2[1:]
    sentence3 = positive_sentence3[0].lower() + positive_sentence3[1:]
    sentence4 = positive_sentence4[0].lower() + positive_sentence4[1:]
    sentence1_n = negative_sentence1[0].lower() + negative_sentence1[1:]
    sentence2_n = negative_sentence2[0].lower() + negative_sentence2[1:]
    sentence3_n = negative_sentence3[0].lower() + negative_sentence3[1:]
    sentence4_n = negative_sentence4[0].lower() + negative_sentence4[1:]
    premise = "If " + sentence1 +", then " + sentence2+". And if "+ sentence3 +", then " + sentence4+". But either "+ sentence2_n + " or " + sentence4_n+"."
    hypothesis = "Either "+ sentence1_n  +" or " + sentence3_n +"."
    return premise,hypothesis

# %%
def bidirectional_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4):
    while positive_sentence1[-1]=='.':
        positive_sentence1 = positive_sentence1[:-1]
    while negative_sentence1[-1]=='.':
        negative_sentence1 = negative_sentence1[:-1]
    while positive_sentence2[-1]=='.':
        positive_sentence2 = positive_sentence2[:-1]
    while negative_sentence2[-1]=='.':
        negative_sentence2 = negative_sentence2[:-1]
    while positive_sentence3[-1]=='.':
        positive_sentence3 = positive_sentence3[:-1]
    while negative_sentence3[-1]=='.':
        negative_sentence3 = negative_sentence3[:-1]
    while positive_sentence4[-1]=='.':
        positive_sentence4 = positive_sentence4[:-1]
    while negative_sentence4[-1]=='.':
        negative_sentence4 = negative_sentence4[:-1]

    sentence1 = positive_sentence1[0].lower() + positive_sentence1[1:]
    sentence2 = positive_sentence2[0].lower() + positive_sentence2[1:]
    sentence3 = positive_sentence3[0].lower() + positive_sentence3[1:]
    sentence4 = positive_sentence4[0].lower() + positive_sentence4[1:]
    sentence1_n = negative_sentence1[0].lower() + negative_sentence1[1:]
    sentence2_n = negative_sentence2[0].lower() + negative_sentence2[1:]
    sentence3_n = negative_sentence3[0].lower() + negative_sentence3[1:]
    sentence4_n = negative_sentence4[0].lower() + negative_sentence4[1:]
    premise = "If " + sentence1 +", then " + sentence2+". And if "+ sentence3 +", then " + sentence4+". But either "+ sentence1 + " or " + sentence4_n+"."
    hypothesis = "Either "+sentence2 +" or " + sentence3_n+"."
    return premise,hypothesis

# %%
def transportation_1(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2):
    while positive_sentence1[-1]=='.':
        positive_sentence1 = positive_sentence1[:-1]
    while negative_sentence1[-1]=='.':
        negative_sentence1 = negative_sentence1[:-1]
    while positive_sentence2[-1]=='.':
        positive_sentence2 = positive_sentence2[:-1]
    while negative_sentence2[-1]=='.':
        negative_sentence2 = negative_sentence2[:-1]

    sentence1 = positive_sentence1[0].lower() + positive_sentence1[1:]
    sentence2 = positive_sentence2[0].lower() + positive_sentence2[1:]
    sentence1_n = negative_sentence1[0].lower() + negative_sentence1[1:]
    sentence2_n = negative_sentence2[0].lower() + negative_sentence2[1:]
    premise =  "If " + sentence1 + ", then " + sentence2 + "."
    hypothesis = "If " + sentence2_n + ", then " + sentence1_n + "."
    return premise,hypothesis

# %%
def transportation_2(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2):
    premise,hypothesis = transportation_1(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2)
    return hypothesis,premise

# %%
def material_implication_1(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2):
    while positive_sentence1[-1]=='.':
        positive_sentence1 = positive_sentence1[:-1]
    while negative_sentence1[-1]=='.':
        negative_sentence1 = negative_sentence1[:-1]
    while positive_sentence2[-1]=='.':
        positive_sentence2 = positive_sentence2[:-1]
    while negative_sentence2[-1]=='.':
        negative_sentence2 = negative_sentence2[:-1]

    sentence1 = positive_sentence1[0].lower() + positive_sentence1[1:]
    sentence2 = positive_sentence2[0].lower() + positive_sentence2[1:]
    sentence1_n = negative_sentence1[0].lower() + negative_sentence1[1:]
    sentence2_n = negative_sentence2[0].lower() + negative_sentence2[1:]
    premise =  "If " + sentence1 + ", then " + sentence2 + "."
    hypothesis = "Either " + sentence1_n + " or " + sentence2 + "."
    return premise,hypothesis

# %%
def material_implication_2(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2):
    premise,hypothesis = material_implication_1(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2)
    return hypothesis,premise

# %%
def negate_hypthesis(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2):
    while positive_sentence1[-1]=='.':
        positive_sentence1 = positive_sentence1[:-1]
    while negative_sentence1[-1]=='.':
        negative_sentence1 = negative_sentence1[:-1]
    while positive_sentence2[-1]=='.':
        positive_sentence2 = positive_sentence2[:-1]
    while negative_sentence2[-1]=='.':
        negative_sentence2 = negative_sentence2[:-1]
    premise = positive_sentence1 +"."
    hypothesis = negative_sentence2 + "."
    return premise,hypothesis

# %%
s1 = "Beads of water can be formed by clouds."
s1n= "Beads of water cannot be formed by clouds."
s2 = "Beads type of water formation is formed by clouds."
s2n = "Beads type of water formation is not formed by clouds."
s3 = "Vapor turning into a liquid leaves behind beads of water"
s3n= "Vapor turning into a liquid does not leave behind beads of water."
s4 = "Beads of water come from vapor turning into a liquid."
s4n = "Beads of water do not come from vapor turning into a liquid."
p,h = bidirectional_dilemma(s1,s1n,s2,s2n,s3,s3n,s4,s4n)
print("Premise:  ", p)
print("Hypothesis: ",h)
# Out:
# Premise:   If beads of water can be formed by clouds, then beads type of water formation is formed by clouds. And if vapor turning into a liquid leaves behind beads of water, then beads of water come from vapor turning into a liquid. But either beads of water can be formed by clouds or beads of water do not come from vapor turning into a liquid.
# Hypothesis:  Either beads type of water formation is formed by clouds or vapor turning into a liquid does not leave behind beads of water.

# %%
df_result = pd.DataFrame(columns=['premise', 'hypothesis','propositional_logic_rule'])
df_result
# Out:
# Empty DataFrame
# Columns: [premise, hypothesis, propositional_logic_rule]
# Index: []

# %%
#Expressions involving 1 row
df_test_entailments = df_test
for i,row in df_test_entailments.iterrows():
    positive_sentence1 = row["Premises"]
    negative_sentence1 = row["Negate Premise"]
    positive_sentence2 = row["Hypothesis"]
    negative_sentence2 = row["Negate Hypothesis"]
    modus_tollens_premise, modus_tollens_hypothesis = modus_tollens(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2)
    row = [modus_tollens_premise, modus_tollens_hypothesis,'Modus Tollens']
    df_result.loc[len(df_result)] = row

    transportation_1_premise, transportation_1_hypothesis = transportation_1(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2)
    row = [transportation_1_premise, transportation_1_hypothesis,'Transportation 1']
    df_result.loc[len(df_result)] = row

    transportation_2_premise, transportation_2_hypothesis = transportation_2(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2)
    row = [transportation_2_premise, transportation_2_hypothesis,'Transportation 2']
    df_result.loc[len(df_result)] = row

    material_implication_1_premise, material_implication_1_hypothesis = material_implication_1(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2)
    row = [material_implication_1_premise, material_implication_1_hypothesis,'Material Implication 1']
    df_result.loc[len(df_result)] = row

    material_implication_2_premise, material_implication_2_hypothesis = material_implication_2(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2)
    row = [material_implication_2_premise, material_implication_2_hypothesis,'Material Implication 2']
    df_result.loc[len(df_result)] = row

    negate_hypthesis_premise, negate_hypthesis_hypothesis = negate_hypthesis(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2)
    row = [negate_hypthesis_premise, negate_hypthesis_hypothesis,'Negate Hypothesis']
    df_result.loc[len(df_result)] = row

# %%
df_result
# Out:
#                                                 premise  \
# 0     If a bolus is moistened food, then moistened F...
# 1     If a bolus is moistened food, then moistened F...
# 2     If moistened food is not a bolus, then a bolus...
# 3     If a bolus is moistened food, then moistened F...
# 4     Either a bolus is not moistened food or moiste...
# ...                                                 ...
# 1111  If renal failure may be treated with dialysis,...
# 1112  If renal failure may not be treated with dialy...
# 1113  If renal failure may be treated with dialysis,...
# 1114  Either renal failure may not always be treated...
# 1115        Renal failure may be treated with dialysis.
#
#                                              hypothesis  \
# 0                        a bolus is not moistened food.
# 1     If moistened food is not a bolus, then a bolus...
# 2     If a bolus is moistened food, then moistened F...
# 3     Either a bolus is not moistened food or moiste...
# 4     If a bolus is moistened food, then moistened F...
# ...                                                 ...
# 1111  If renal failure may not be treated with dialy...
# 1112  If renal failure may be treated with dialysis,...
# 1113  Either renal failure may not always be treated...
# 1114  If renal failure may be treated with dialysis,...
# 1115    Renal failure may not be treated with dialysis.
#
#      propositional_logic_rule
# 0               Modus Tollens
# 1            Transportation 1
# 2            Transportation 2
# 3      Material Implication 1
# 4      Material Implication 2
# ...                       ...
# 1111         Transportation 1
# 1112         Transportation 2
# 1113   Material Implication 1
# 1114   Material Implication 2
# 1115        Negate Hypothesis
#
# [1116 rows x 3 columns]

# %%
df_test_entailments.shape
# Out:
# (185, 4)

# %%
#Expressions involving 2 rows
positive_sentence1 = df_test_entailments.iloc[0]["Premises"]
negative_sentence1 = df_test_entailments.iloc[0]["Negate Premise"]
positive_sentence2 = df_test_entailments.iloc[0]["Hypothesis"]
negative_sentence2 = df_test_entailments.iloc[0]["Negate Hypothesis"]

positive_sentence3 = ""
negative_sentence3 = ""
positive_sentence4 = ""
negative_sentence4 = ""
for i,row in df_test_entailments.iterrows():
    #Set first 2 sentences
    if i==0:
        continue
    positive_sentence3 = row["Premises"]
    negative_sentence3 = row["Negate Premise"]
    positive_sentence4 = row["Hypothesis"]
    negative_sentence4 = row["Negate Hypothesis"]

    constructive_dilemma_premise, constructive_dilemma_hypothesis = constructive_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4)
    row = [constructive_dilemma_premise, constructive_dilemma_hypothesis,'Constructive Dilemma']
    df_result.loc[len(df_result)] = row

    destructive_dilemma_premise, destructive_dilemma_hypothesis = destructive_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4)
    row = [destructive_dilemma_premise, destructive_dilemma_hypothesis,'Destructive Dilemma']
    df_result.loc[len(df_result)] = row

    bidirectional_dilemma_premise, bidirectional_dilemma_hypothesis = bidirectional_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4)
    row = [bidirectional_dilemma_premise, bidirectional_dilemma_hypothesis,'Bidirectional Dilemma']
    df_result.loc[len(df_result)] = row

    positive_sentence1 = positive_sentence3
    negative_sentence1 = negative_sentence3
    positive_sentence2 = positive_sentence4
    negative_sentence2 = negative_sentence4

# %%
positive_sentence3 = df_test_entailments.iloc[0]["Premises"]
negative_sentence3 = df_test_entailments.iloc[0]["Negate Premise"]
positive_sentence4 = df_test_entailments.iloc[0]["Hypothesis"]
negative_sentence4 = df_test_entailments.iloc[0]["Negate Hypothesis"]

constructive_dilemma_premise, constructive_dilemma_hypothesis = constructive_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4)
row = [constructive_dilemma_premise, constructive_dilemma_hypothesis,'Constructive Dilemma']
df_result.loc[len(df_result)] = row

destructive_dilemma_premise, destructive_dilemma_hypothesis = destructive_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4)
row = [destructive_dilemma_premise, destructive_dilemma_hypothesis,'Destructive Dilemma']
df_result.loc[len(df_result)] = row

bidirectional_dilemma_premise, bidirectional_dilemma_hypothesis = bidirectional_dilemma(positive_sentence1, negative_sentence1, positive_sentence2, negative_sentence2, positive_sentence3, negative_sentence3, positive_sentence4, negative_sentence4)
row = [bidirectional_dilemma_premise, bidirectional_dilemma_hypothesis,'Bidirectional Dilemma']
df_result.loc[len(df_result)] = row

# %%
for i,row in df_result.iterrows():
    p = row["premise"]
    h = row["hypothesis"]
    # if (". or" in p) ==True:
    #     print("Inside 1")
    if (".." in h) ==True:
        print(row["propositional_logic_rule"])

# %%
df_result
# Out:
#                                                 premise  \
# 0     If a bolus is moistened food, then moistened F...
# 1     If a bolus is moistened food, then moistened F...
# 2     If moistened food is not a bolus, then a bolus...
# 3     If a bolus is moistened food, then moistened F...
# 4     Either a bolus is not moistened food or moiste...
# ...                                                 ...
# 1669  If kidney failure may be treated by cleaning t...
# 1670  If kidney failure may be treated by cleaning t...
# 1671  If renal failure may be treated with dialysis,...
# 1672  If renal failure may be treated with dialysis,...
# 1673  If renal failure may be treated with dialysis,...
#
#                                              hypothesis  \
# 0                        a bolus is not moistened food.
# 1     If moistened food is not a bolus, then a bolus...
# 2     If a bolus is moistened food, then moistened F...
# 3     Either a bolus is not moistened food or moiste...
# 4     If a bolus is moistened food, then moistened F...
# ...                                                 ...
# 1669  Either kidney failure may not always be treate...
# 1670  Either kidney failure may be treated by cleani...
# 1671  Either renal failure may be treated with dialy...
# 1672  Either renal failure may not always be treated...
# 1673  Either renal failure may be treated with dialy...
#
#      propositional_logic_rule
# 0               Modus Tollens
# 1            Transportation 1
# 2            Transportation 2
# 3      Material Implication 1
# 4      Material Implication 2
# ...                       ...
# 1669      Destructive Dilemma
# 1670    Bidirectional Dilemma
# 1671     Constructive Dilemma
# 1672      Destructive Dilemma
# 1673    Bidirectional Dilemma
#
# [1674 rows x 3 columns]

# %%
df_result.to_csv('Set_5_Attacks_Dataset_Sanket.csv')

# %%
a = df_result[df_result["propositional_logic_rule"]=="Destructive Dilemma"]["premise"].head(1)

# %%
a
# Out:
# 1117    If a bolus is moistened food, then moistened F...
# Name: premise, dtype: object
